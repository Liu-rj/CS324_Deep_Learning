# %%
from IPython.display import Image

# %%
print('At the start of training')
Image(filename='images/0.png')
# Out:
# At the start of training

# %%
print('Half way throught the training')
Image(filename='images/52000.png')
# Out:
# Half way throught the training

# %%
print('After training has terminated')
Image(filename='images/187500.png')
# Out:
# After training has terminated
